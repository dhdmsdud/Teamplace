# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# file loading

population_DF = pd.read_csv('../data/population.csv', encoding='cp949', thousands=',').iloc[:,:13]
population_DF
# Out:
#                               행정구역  2021년01월_계_총인구수  2021년01월_계_연령구간인구수  \
# 0              서울특별시  (1100000000)          9657969             9657969
# 1           서울특별시 종로구 (1111000000)           149125              149125
# 2      서울특별시 종로구 청운효자동(1111051500)            12426               12426
# 3        서울특별시 종로구 사직동(1111053000)             9544                9544
# 4        서울특별시 종로구 삼청동(1111054000)             2613                2613
# ...                            ...              ...                 ...
# 3841  제주특별자치도 서귀포시 서홍동(5013058000)            10743               10743
# 3842  제주특별자치도 서귀포시 대륜동(5013059000)            14826               14826
# 3843  제주특별자치도 서귀포시 대천동(5013060000)            13900               13900
# 3844  제주특별자치도 서귀포시 중문동(5013061000)            11543               11543
# 3845  제주특별자치도 서귀포시 예래동(5013062000)             3934                3934
#
#       2021년01월_계_0~9세  2021년01월_계_10~19세  2021년01월_계_20~29세  \
# ...

# %%
# search

name = input('원하는 지역의 이름을 입력해주세요 : ')
section = population_DF[population_DF['행정구역'].str.contains(name)].iloc[:, :10]
section
# Out:
# 원하는 지역의 이름을 입력해주세요 : 안양
#                               행정구역  2021년01월_계_총인구수  2021년01월_계_연령구간인구수  \
# 1389          경기도 안양시 (4117000000)           549730              549730
# 1390      경기도 안양시 만안구 (4117100000)           239070              239070
# 1391  경기도 안양시 만안구 안양1동(4117151000)            12681               12681
# 1392  경기도 안양시 만안구 안양2동(4117152000)            21841               21841
# 1393  경기도 안양시 만안구 안양3동(4117153000)            16775               16775
# 1394  경기도 안양시 만안구 안양4동(4117154000)             7281                7281
# 1395  경기도 안양시 만안구 안양5동(4117155000)            10663               10663
# 1396  경기도 안양시 만안구 안양6동(4117156000)            21077               21077
# 1397  경기도 안양시 만안구 안양7동(4117157000)            15847               15847
# 1398  경기도 안양시 만안구 안양8동(4117158000)            11023               11023
# 1399  경기도 안양시 만안구 안양9동(4117158100)            17640               17640
# 1400  경기도 안양시 만안구 석수1동(4117159000)            19885               19885
# ...

# %%
# 그래프

plt.rc('font', family='Malgun Gothic')
population_DF.plot()
plt.show()
